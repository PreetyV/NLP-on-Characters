# %%
import zipfile
import os
import glob
# !pip install -U textblob
# !python -m textblob.download_corpora
path = ".\\"
from nltk import tokenize
import re
# Out:
# Collecting textblob
#   Downloading https://files.pythonhosted.org/packages/60/f0/1d9bfcc8ee6b83472ec571406bd0dd51c0e6330ff1a51b2d29861d389e85/textblob-0.15.3-py2.py3-none-any.whl (636kB)
# Requirement not upgraded as not directly required: nltk>=3.1 in c:\users\krish\anaconda\lib\site-packages (from textblob) (3.3)
# Requirement not upgraded as not directly required: six in c:\users\krish\anaconda\lib\site-packages (from nltk>=3.1->textblob) (1.11.0)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.3
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# tensorboard 2.0.0 has requirement setuptools>=41.0.0, but you'll have setuptools 40.2.0 which is incompatible.
# You are using pip version 10.0.1, however version 19.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\krish\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\krish\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\krish\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\krish\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\krish\AppData\Roaming\nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\krish\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.
# C:\Users\krish\Anaconda\lib\site-packages\sklearn\feature_extraction\text.py:17: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Mapping, defaultdict

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    return score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-4fd235a25b32> in <module>()
# ----> 1 from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
#       2 analyser = SentimentIntensityAnalyzer()
#       3 def sentiment_analyzer_scores(sentence):
#       4     score = analyser.polarity_scores(sentence)
#       5     return score
#
# ModuleNotFoundError: No module named 'vaderSentiment'

# %%
maletext = []
femaletext = []
current = 'm'
# string output = input.Substring(input.IndexOf('[^a-zA-Z]*') + 1);

# %%
for r,d,f in os.walk(path):
    for filename in f:
        if ".zip" in filename:
            with zipfile.ZipFile(filename) as myzip:
                for f in myzip.infolist():
                    if ".txt" in f.filename and "_MACOSX" not in f.filename:
                        print(f.filename)
                        archive = myzip.read(f.filename)
                        content = archive.decode('utf-8') 
#                         print(content)
                        for line in tokenize.sent_tokenize(content):
                            line = line.replace(':','. ').replace('\n','.').replace('\\','')
                            if len(re.findall('[0-9]+', line)) == 0:
                                if (line[0] == 'H'):
                                    maletext.append(line)
                                    current = 'm'
                                elif (line[0] == 'S'):
                                    femaletext.append(line)
                                    current = 'f'
                                    
                                elif (line[0] == 'a'):
                                    if "she" in f.filename:
                                        line = "She's " + line
                                        femaletext.append(line)
                                        current = 'f'
                                    else:
                                        line = "He's " + line
                                        maletext.append(line) 
                                        current = 'm'
                                else:
                                    if current == 'm':
                                        maletext[-1]= maletext[-1]+" "+ line
                                    elif current == 'f':
                                        femaletext[-1]= femaletext[-1]+" "+ line
maletext = [male.replace('\r','').replace('\n','') for male in maletext]
print ("=========================================================")
femaletext = [female.replace('\r','').replace('\n','') for female in femaletext]
#                             line = line
#                             if(len(line)>5 and not bool(re.search(r'\d', line))):
#                                 print(line.strip())
#                         print([ele for ele in tokenize.sent_tokenize(content) if len(ele)>3])
# Out:
# hes.txt
# shes.txt
# 595/male.txt
# 595/female.txt
# female.txt
# male.txt
# 595 result/SHE.txt
# 595 result/HE.txt
# 595 result/SHE.txt
# 595 result/HE.txt
# femalefile.txt
# malefile.txt
# FE595 H2 /female.txt
# FE595 H2 /male.txt
# male.txt
# female.txt
# FE595_Characters/he.txt
# FE595_Characters/she.txt
# female.txt
# male.txt
# FemaleHeroes.txt
# MaleHeroes.txt
# Helist.txt
# Shelist.txt
# HW1 Results/hesfile.txt
# HW1 Results/shesfile.txt
# Results/Male.txt
# Results/Female.txt
# text/she.txt
# text/he.txt
# =========================================================

# %%
print(sentiment_analyzer_scores("He's a shy day-dreaming cat burglar who dotes on his loving old ma.")["compound"])
# Out:
# 0.4404

# %%
m = {x:[maletext.count(x),sentiment_analyzer_scores(x)["compound"]] for x in maletext}

# %%
print(m)
# Out:
